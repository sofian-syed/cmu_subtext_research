# %%
from convokit import Corpus, download

# Download and load the GAP Corpus
gap_corpus = Corpus(filename=download("gap-corpus"))
print("GAP Corpus loaded successfully!")
gap_corpus.print_summary_stats()
# Out:
# Dataset already exists at /Users/sofiansyed/.convokit/saved-corpora/gap-corpus
# GAP Corpus loaded successfully!
# Number of Speakers: 84
# Number of Utterances: 8009
# Number of Conversations: 28

# %%
import pandas as pd
from convokit import Corpus, download

# Extracts each speaker's Ind_Lead score (self-perceived leadership).
# Maps it to a descriptive label (e.g., "Very High").

score_mapping = {
    1: "Very Low",
    2: "Low",
    3: "Moderate",
    4: "High",
    5: "Very High"
}


speakers_data = []
# Iterate over speaker objects using iter_speakers()
for speaker in gap_corpus.iter_speakers():
    # Get the leadership score from metadata and ensure it's an integer if possible
    score = speaker.meta.get("Ind_Lead", None)
    try:
        score = int(score)
    except (ValueError, TypeError):
        score = None

    # Map the numeric score to a descriptive label, if available
    score_label = score_mapping.get(score, "N/A") if score is not None else "N/A"
    
    conversation_id = speaker.id.split('.')[0]
    
    speakers_data.append({
        "Conversation": conversation_id,
        "Speaker": speaker.id,
        "   Numeric Leadership Score   ": score if score is not None else "N/A",
        "Descriptive Leadership": score_label
    })

df = pd.DataFrame(speakers_data)
df.sort_values(by=["Conversation", "Speaker"], inplace=True)
for conversation, group in df.groupby("Conversation"):
    print("="*50)
    print(f"Conversation {conversation}")
    print("="*50)
    print(group.to_string(index=False))
    print("\n")
# Out:
# ==================================================
# Conversation 1
# ==================================================
# Conversation Speaker     Numeric Leadership Score    Descriptive Leadership
#            1  1.Blue                               2                    Low
#            1 1.Green                               4                   High
#            1  1.Pink                               5              Very High
#
#
# ==================================================
# Conversation 10
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           10 10.Orange                               4                   High
#           10   10.Pink                               3               Moderate
#
#
# ==================================================
# Conversation 11
# ==================================================
# Conversation  Speaker     Numeric Leadership Score    Descriptive Leadership
#           11 11.Green                               5              Very High
#           11  11.Pink                               4                   High
#
#
# ==================================================
# Conversation 12
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           12   12.Blue                               3               Moderate
#           12  12.Green                               3               Moderate
#           12 12.Orange                               4                   High
#           12   12.Pink                               4                   High
#
#
# ==================================================
# Conversation 13
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           13   13.Blue                               4                   High
#           13 13.Yellow                               4                   High
#
#
# ==================================================
# Conversation 14
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           14   14.Blue                               3               Moderate
#           14   14.Pink                               1               Very Low
#           14    14.Red                               5              Very High
#           14 14.Yellow                               2                    Low
#
#
# ==================================================
# Conversation 15
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           15   15.Blue                               3               Moderate
#           15 15.Orange                               4                   High
#           15 15.Purple                               4                   High
#           15 15.Yellow                               4                   High
#
#
# ==================================================
# Conversation 16
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           16   16.Blue                               5              Very High
#           16   16.Pink                               3               Moderate
#           16 16.Yellow                               5              Very High
#
#
# ==================================================
# Conversation 17
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           17   17.Blue                               4                   High
#           17 17.Orange                               4                   High
#           17   17.Pink                               3               Moderate
#           17 17.Yellow                               3               Moderate
#
#
# ==================================================
# Conversation 18
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           18   18.Blue                               3               Moderate
#           18 18.Orange                               3               Moderate
#           18   18.Pink                               4                   High
#
#
# ==================================================
# Conversation 19
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           19   19.Blue                               4                   High
#           19 19.Orange                               3               Moderate
#           19   19.Pink                               3               Moderate
#
#
# ==================================================
# Conversation 2
# ==================================================
# Conversation Speaker     Numeric Leadership Score    Descriptive Leadership
#            2  2.Blue                               4                   High
#            2  2.Pink                               3               Moderate
#
#
# ==================================================
# Conversation 20
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           20   20.Blue                               4                   High
#           20 20.Orange                               2                    Low
#           20   20.Pink                               3               Moderate
#
#
# ==================================================
# Conversation 21
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           21   21.Blue                               5              Very High
#           21 21.Orange                               1               Very Low
#           21   21.Pink                               4                   High
#
#
# ==================================================
# Conversation 22
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           22   22.Blue                               4                   High
#           22 22.Orange                               3               Moderate
#           22   22.Pink                               3               Moderate
#
#
# ==================================================
# Conversation 23
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           23   23.Blue                               3               Moderate
#           23 23.Orange                               5              Very High
#
#
# ==================================================
# Conversation 24
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           24   24.Blue                               4                   High
#           24 24.Orange                               2                    Low
#           24   24.Pink                               2                    Low
#
#
# ==================================================
# Conversation 25
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           25   25.Blue                               3               Moderate
#           25 25.Orange                               4                   High
#           25   25.Pink                               5              Very High
#
#
# ==================================================
# Conversation 26
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           26   26.Blue                               2                    Low
#           26 26.Orange                               4                   High
#           26   26.Pink                               4                   High
#
#
# ==================================================
# Conversation 27
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           27   27.Blue                               3               Moderate
#           27 27.Orange                               4                   High
#           27   27.Pink                               3               Moderate
#
#
# ==================================================
# Conversation 28
# ==================================================
# Conversation   Speaker     Numeric Leadership Score    Descriptive Leadership
#           28   28.Blue                               5              Very High
#           28 28.Orange                               4                   High
#           28   28.Pink                               4                   High
#
#
# ==================================================
# Conversation 3
# ==================================================
# Conversation Speaker     Numeric Leadership Score    Descriptive Leadership
#            3 3.Green                               4                   High
#            3  3.Pink                               3               Moderate
#
#
# ==================================================
# Conversation 4
# ==================================================
# Conversation  Speaker     Numeric Leadership Score    Descriptive Leadership
#            4   4.Blue                               5              Very High
#            4 4.Orange                               3               Moderate
#            4 4.Yellow                               2                    Low
#
#
# ==================================================
# Conversation 5
# ==================================================
# Conversation  Speaker     Numeric Leadership Score    Descriptive Leadership
#            5   5.Blue                               4                   High
#            5 5.Orange                               3               Moderate
#            5   5.Pink                               3               Moderate
#            5 5.Yellow                               3               Moderate
#
#
# ==================================================
# Conversation 6
# ==================================================
# Conversation  Speaker     Numeric Leadership Score    Descriptive Leadership
#            6   6.Blue                               2                    Low
#            6  6.Green                               5              Very High
#            6 6.Orange                               3               Moderate
#            6   6.Pink                               4                   High
#
#
# ==================================================
# Conversation 7
# ==================================================
# Conversation  Speaker     Numeric Leadership Score    Descriptive Leadership
#            7   7.Blue                               2                    Low
#            7  7.Green                               3               Moderate
#            7 7.Orange                               3               Moderate
#
#
# ==================================================
# Conversation 8
# ==================================================
# Conversation  Speaker     Numeric Leadership Score    Descriptive Leadership
#            8   8.Blue                               3               Moderate
#            8  8.Green                               5              Very High
#            8 8.Orange                               3               Moderate
#
#
# ==================================================
# Conversation 9
# ==================================================
# Conversation Speaker     Numeric Leadership Score    Descriptive Leadership
#            9  9.Blue                               2                    Low
#            9 9.Green                               4                   High
#            9  9.Pink                               2                    Low

# %%
from collections import defaultdict
from convokit import Corpus, download
from convokit.coordination import Coordination
import numpy as np

# Uses ConvoKit’s Coordination transformer to measure linguistic coordination (e.g., matching pronouns, articles).
# Computes:
# Raw coordination scores
# 3 weighted versions (Eq1, Eq2, Eq3)
# Average of the 3 equations
# A final score (average of raw + weighted)
# Groups speakers by conversation.
# Prints all these values in a  table and identifies the highest scorer per group.

coord = Coordination(coordination_attribute_name='coord')
# Fit the transformer on the corpus and transform it.
# This annotates each speaker in the corpus with coordination scores stored in their meta.
gap_corpus = coord.fit_transform(gap_corpus)

# Equation 2: "Communication Influence" weighting (emphasizes auxverb, conj, adverb)
weights_eq2 = {
    "article": 1.0,
    "auxverb": 1.5,
    "conj": 2.0,
    "adverb": 2.0,
    "ppron": 1.0,
    "ipron": 1.0,
    "preps": 0.5,
    "quant": 0.5
}
# Equation 3: "Structural Emphasis" weighting (emphasizes conj and preps)
weights_eq3 = {
    "article": 0.5,
    "auxverb": 1.0,
    "conj": 2.5,
    "adverb": 1.0,
    "ppron": 0.5,
    "ipron": 0.5,
    "preps": 2.0,
    "quant": 0.5
}

# Function to compute weighted averages from a marker dictionary.
def compute_target_scores(marker_dict):
    # Collect numeric values.
    values = [v for v in marker_dict.values() if isinstance(v, (int, float))]
    if not values:
        return None, None, None
    # Equation 1: Equal weighting -> simple average.
    eq1 = np.mean(values)
    
    # Equation 2: Communication Influence weighting.
    num2, den2 = 0.0, 0.0
    for marker, value in marker_dict.items():
        if isinstance(value, (int, float)) and marker in weights_eq2:
            num2 += weights_eq2[marker] * value
            den2 += weights_eq2[marker]
    eq2 = num2 / den2 if den2 != 0 else None

    # Equation 3: Structural Emphasis weighting.
    num3, den3 = 0.0, 0.0
    for marker, value in marker_dict.items():
        if isinstance(value, (int, float)) and marker in weights_eq3:
            num3 += weights_eq3[marker] * value
            den3 += weights_eq3[marker]
    eq3 = num3 / den3 if den3 != 0 else None

    return eq1, eq2, eq3

conversation_groups = defaultdict(list)

# Process each speaker in the corpus.
for speaker in gap_corpus.iter_speakers():
    # Extract conversation group from speaker id (e.g., "1.Pink" -> "1")
    conv_group = speaker.id.split('.')[0]
    # Initialize lists to hold target-level scores for aggregation.
    raw_list = []   # raw final score: sum of all pairwise scores
    eq1_list = []   # Equation 1 scores per target
    eq2_list = []   # Equation 2 scores per target
    eq3_list = []   # Equation 3 scores per target
    
    # Get the coordination data for this speaker.
    coordination_data = speaker.meta.get('coord', {})
    
    for target, score in coordination_data.items():
        # If score is a dictionary, check if an 'overall' key exists.
        if isinstance(score, dict):
            if 'overall' in score:
                overall_val = score['overall']
                raw_list.append(overall_val)
                eq1_list.append(overall_val)
                eq2_list.append(overall_val)
                eq3_list.append(overall_val)
            else:
                res = compute_target_scores(score)
                if res[0] is not None:
                    eq1_list.append(res[0])
                    eq2_list.append(res[1])
                    eq3_list.append(res[2])
                    raw_list.append(np.sum([v for v in score.values() if isinstance(v, (int, float))]))
        elif isinstance(score, (int, float)):
            raw_list.append(score)
            eq1_list.append(score)
            eq2_list.append(score)
            eq3_list.append(score)
    
    # Compute aggregated scores per speaker.
    aggregated_eq1 = np.mean(eq1_list) if eq1_list else None
    aggregated_eq2 = np.mean(eq2_list) if eq2_list else None
    aggregated_eq3 = np.mean(eq3_list) if eq3_list else None
    aggregated_raw = np.sum(raw_list) if raw_list else None
    
    # Compute the average of the three equation scores.
    avg_weighted = None
    if aggregated_eq1 is not None and aggregated_eq2 is not None and aggregated_eq3 is not None:
        avg_weighted = (aggregated_eq1 + aggregated_eq2 + aggregated_eq3) / 3

    # Final score is 50% from the aggregated raw score and 50% from the average of the three equation scores.
    final_score = None
    if aggregated_raw is not None and avg_weighted is not None:
        final_score = 0.5 * aggregated_raw + 0.5 * avg_weighted
    
    speaker_aggregated = {
        "id": speaker.id,
        "raw_final": aggregated_raw,
        "eq1": aggregated_eq1,
        "eq2": aggregated_eq2,
        "eq3": aggregated_eq3,
        "avg_weighted": avg_weighted,
        "final": final_score
    }
    
    # Append the speaker data object to its conversation group.
    conversation_groups[conv_group].append(speaker_aggregated)

# STEP 3: Sort by Conversation Group and Print
print("\n=== Detailed Coordination Scores, Final Scores, and Winners by Conversation Group ===\n")
for conv in sorted(conversation_groups.keys(), key=lambda x: int(x)):
    print("=" * 100)
    print(f"Conversation Group: {conv}")
    print("=" * 100)
    header = (f"{'Speaker':<10} {'Raw Final':>10}   {'Eq1 (Equal)':>12}   "
              f"{'Eq2 (Comm Inf.)':>16}   {'Eq3 (Struct Emph.)':>18}   "
              f"{'Avg Weighted':>14}   {'Final Score':>12}")
    print(header)
    print("-" * len(header))
    
    winner = None
    highest_final = -np.inf
    for s_data in conversation_groups[conv]:
        s_id = s_data["id"]
        raw_final = s_data["raw_final"]
        eq1 = s_data["eq1"]
        eq2 = s_data["eq2"]
        eq3 = s_data["eq3"]
        avg_weighted = s_data["avg_weighted"]
        final = s_data["final"]
        
        print(f"{s_id:<10} {raw_final:10.4f}   {eq1:12.4f}   {eq2:16.4f}   {eq3:18.4f}   {avg_weighted:14.4f}   {final:12.4f}")
        
        if final is not None and final > highest_final:
            highest_final = final
            winner = s_id
            
    print("-" * len(header))
    print(f"Winner (highest Final Score): {winner} with a score of {highest_final:.4f}")
    print("\n")
# Out:
# === Detailed Coordination Scores, Final Scores, and Winners by Conversation Group ===
#
# ====================================================================================================
# Conversation Group: 1
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 1.Pink         0.8485         0.0530             0.0607               0.0547           0.0561         0.4523
# 1.Blue        -0.4588        -0.0278            -0.0302              -0.0329          -0.0303        -0.2445
# 1.Green        2.0156         0.1440             0.1512               0.0906           0.1286         1.0721
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 1.Green with a score of 1.0721
#
#
# ====================================================================================================
# Conversation Group: 2
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 2.Pink         0.2361         0.0295             0.0395               0.0337           0.0343         0.1352
# 2.Blue        -0.3697        -0.0528            -0.0529              -0.0548          -0.0535        -0.2116
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 2.Pink with a score of 0.1352
#
#
# ====================================================================================================
# Conversation Group: 3
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 3.Green       -1.2043        -0.1505            -0.1436              -0.1459          -0.1467        -0.6755
# 3.Pink        -0.7858        -0.0982            -0.1046              -0.1124          -0.1050        -0.4454
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 3.Pink with a score of -0.4454
#
#
# ====================================================================================================
# Conversation Group: 4
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 4.Blue        -0.4531        -0.0324            -0.0724              -0.0680          -0.0576        -0.2553
# 4.Orange      -0.3170        -0.0453            -0.0484              -0.0704          -0.0547        -0.1858
# 4.Yellow      -0.6619        -0.0489            -0.0373              -0.0867          -0.0577        -0.3598
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 4.Orange with a score of -0.1858
#
#
# ====================================================================================================
# Conversation Group: 5
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 5.Orange       0.8692         0.0375             0.0438               0.0717           0.0510         0.4601
# 5.Blue        -0.6515        -0.0293            -0.0458              -0.0440          -0.0397        -0.3456
# 5.Pink        -0.3224        -0.0127            -0.0129              -0.0002          -0.0086        -0.1655
# 5.Yellow      -0.8575        -0.0540            -0.0650              -0.0802          -0.0664        -0.4620
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 5.Orange with a score of 0.4601
#
#
# ====================================================================================================
# Conversation Group: 6
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 6.Blue        -0.0252         0.0369             0.0416               0.0149           0.0312         0.0030
# 6.Pink        -1.1234        -0.0616            -0.0727              -0.0981          -0.0775        -0.6004
# 6.Green       -0.0831         0.0273             0.0237               0.0355           0.0288        -0.0271
# 6.Orange       2.5365         0.1584             0.1364               0.1451           0.1466         1.3416
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 6.Orange with a score of 1.3416
#
#
# ====================================================================================================
# Conversation Group: 7
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 7.Orange       0.8107         0.0507             0.0681               0.0614           0.0601         0.4354
# 7.Green        0.0756         0.0047            -0.0066               0.0014          -0.0002         0.0377
# 7.Blue         0.5330         0.0355             0.0209               0.0170           0.0245         0.2787
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 7.Orange with a score of 0.4354
#
#
# ====================================================================================================
# Conversation Group: 8
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 8.Blue        -0.6209        -0.0387            -0.0564              -0.0735          -0.0562        -0.3386
# 8.Green        1.3886         0.0868             0.1004               0.0906           0.0926         0.7406
# 8.Orange       0.2505         0.0157             0.0127              -0.0073           0.0070         0.1288
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 8.Green with a score of 0.7406
#
#
# ====================================================================================================
# Conversation Group: 9
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 9.Green        0.5532         0.0419             0.0219               0.0574           0.0404         0.2968
# 9.Blue        -0.2399        -0.0083             0.0189               0.0061           0.0056        -0.1171
# 9.Pink         0.0542         0.0068             0.0229               0.0124           0.0140         0.0341
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 9.Green with a score of 0.2968
#
#
# ====================================================================================================
# Conversation Group: 10
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 10.Orange     -0.2646        -0.0331            -0.0357              -0.0299          -0.0329        -0.1488
# 10.Pink        0.0307         0.0038            -0.0448              -0.0456          -0.0288         0.0009
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 10.Pink with a score of 0.0009
#
#
# ====================================================================================================
# Conversation Group: 11
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 11.Pink        0.1976         0.0247             0.0210               0.0212           0.0223         0.1099
# 11.Green      -0.5058        -0.0632            -0.0617              -0.0716          -0.0655        -0.2856
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 11.Pink with a score of 0.1099
#
#
# ====================================================================================================
# Conversation Group: 12
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 12.Blue       -0.4155        -0.0250            -0.0365              -0.0343          -0.0319        -0.2237
# 12.Green      -0.9917        -0.0882            -0.0862              -0.0923          -0.0889        -0.5403
# 12.Pink       -0.0070         0.0562             0.0416               0.0342           0.0440         0.0185
# 12.Orange     -0.6500        -0.0812            -0.0790              -0.0700          -0.0767        -0.3634
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 12.Pink with a score of 0.0185
#
#
# ====================================================================================================
# Conversation Group: 13
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 13.Yellow      0.7752         0.1107             0.0677               0.0841           0.0875         0.4313
# 13.Blue       -0.2714        -0.0339            -0.0445              -0.0483          -0.0422        -0.1568
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 13.Yellow with a score of 0.4313
#
#
# ====================================================================================================
# Conversation Group: 14
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 22.Pink with a score of 0.3522
#
#
# ====================================================================================================
# Conversation Group: 23
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 23.Orange     -0.0818        -0.0102             0.0004              -0.0147          -0.0082        -0.0450
# 23.Blue       -0.3936        -0.0492            -0.0504              -0.0483          -0.0493        -0.2215
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 23.Orange with a score of -0.0450
#
#
# ====================================================================================================
# Conversation Group: 24
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 24.Blue       -0.0152         0.0004             0.0022               0.0015           0.0014        -0.0069
# 24.Orange     -0.9879        -0.0617            -0.0740              -0.0650          -0.0669        -0.5274
# 24.Pink       -0.9575        -0.0700            -0.0611              -0.0454          -0.0588        -0.5082
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 24.Blue with a score of -0.0069
#
#
# ====================================================================================================
# Conversation Group: 25
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 25.Pink       -0.6724        -0.0423            -0.0518              -0.0439          -0.0460        -0.3592
# 25.Orange      0.2568         0.0206             0.0052              -0.0217           0.0013         0.1291
# 25.Blue       -0.7482        -0.0498            -0.0610              -0.0319          -0.0476        -0.3979
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 25.Orange with a score of 0.1291
#
#
# ====================================================================================================
# Conversation Group: 26
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 26.Pink        0.1615         0.0321             0.0520               0.0081           0.0307         0.0961
# 26.Blue       -0.2280        -0.0036            -0.0047               0.0055          -0.0009        -0.1145
# 26.Orange     -0.6846        -0.1755            -0.1970              -0.1835          -0.1854        -0.4350
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 26.Pink with a score of 0.0961
#
#
# ====================================================================================================
# Conversation Group: 27
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 27.Pink       -0.7859        -0.2436            -0.2500              -0.2477          -0.2471        -0.5165
# 27.Orange      0.3753         0.0235             0.0220              -0.0174           0.0094         0.1923
# 27.Blue        0.3229         0.0202             0.0139               0.0081           0.0141         0.1685
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 27.Orange with a score of 0.1923
#
#
# ====================================================================================================
# Conversation Group: 28
# ====================================================================================================
# Speaker     Raw Final    Eq1 (Equal)    Eq2 (Comm Inf.)   Eq3 (Struct Emph.)     Avg Weighted    Final Score
# ------------------------------------------------------------------------------------------------------------
# 28.Blue       -0.2727        -0.0185            -0.0139              -0.0186          -0.0170        -0.1449
# 28.Orange     -0.4631        -0.0289            -0.0414              -0.0411          -0.0371        -0.2501
# 28.Pink       -0.3010        -0.0190            -0.0017              -0.0385          -0.0198        -0.1604
# ------------------------------------------------------------------------------------------------------------
# Winner (highest Final Score): 28.Blue with a score of -0.1449

# %%
# Compare Winners for Each Coordination Scheme with Self-Perceived Leader (Allowing Ties)

# Build a dictionary mapping speaker id to their self-perceived leadership score.
self_lead_dict = {}
for speaker in gap_corpus.iter_speakers():
    try:
        self_lead_dict[speaker.id] = float(speaker.meta.get("Ind_Lead", 0))
    except (TypeError, ValueError):
        self_lead_dict[speaker.id] = 0

# Define the coordination schemes (columns) to evaluate.
schemes = ["raw_final", "eq1", "eq2", "eq3", "avg_weighted", "final"]

scheme_match_counts = {scheme: 0 for scheme in schemes}
total_groups = 0

print("\n=== Leader Comparison for Each Coordination Scheme by Conversation Group ===\n")
for conv in sorted(conversation_groups.keys(), key=lambda x: int(x)):
    total_groups += 1
    group = conversation_groups[conv]
    
    # Determine the self-perceived leader(s) for this group (allowing ties).
    highest_self = -np.inf
    self_winners = []
    for s_data in group:
        s_id = s_data["id"]
        self_rating = self_lead_dict.get(s_id, 0)
        if self_rating > highest_self:
            highest_self = self_rating
            self_winners = [s_id]
        elif self_rating == highest_self:
            self_winners.append(s_id)
    
    print("=" * 100)
    print(f"Conversation Group: {conv}")
    print(f"Self-Perceived Leader(s): {', '.join(self_winners)} (Ind_Lead: {highest_self:.4f})")
    print("=" * 100)
    
    # For each coordination scheme, determine the winner(s) and compare.
    for scheme in schemes:
        highest_value = -np.inf
        scheme_winners = []
        for s_data in group:
            score = s_data.get(scheme)
            if score is not None:
                if score > highest_value:
                    highest_value = score
                    scheme_winners = [s_data["id"]]
                elif score == highest_value:
                    scheme_winners.append(s_data["id"])
        
        # Check if any of the scheme winners match any of the self-perceived winners.
        match = any(winner in self_winners for winner in scheme_winners)
        if match:
            scheme_match_counts[scheme] += 1
        
        print(f"Scheme '{scheme}':")
        print(f"  Model Winner(s): {', '.join(scheme_winners)} (Score: {highest_value:.4f})")
        print(f"  Match with self-perceived leader(s): {'Yes' if match else 'No'}")
        print("-" * 100)
    print("\n")
# Out:
# === Leader Comparison for Each Coordination Scheme by Conversation Group ===
#
# ====================================================================================================
# Conversation Group: 1
# Self-Perceived Leader(s): 1.Pink (Ind_Lead: 5.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 1.Green (Score: 2.0156)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 1.Green (Score: 0.1440)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 1.Green (Score: 0.1512)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 1.Green (Score: 0.0906)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 1.Green (Score: 0.1286)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 1.Green (Score: 1.0721)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 2
# Self-Perceived Leader(s): 2.Blue (Ind_Lead: 4.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 2.Pink (Score: 0.2361)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 2.Pink (Score: 0.0295)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 2.Pink (Score: 0.0395)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 2.Pink (Score: 0.0337)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 2.Pink (Score: 0.0343)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 2.Pink (Score: 0.1352)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 3
# Self-Perceived Leader(s): 3.Green (Ind_Lead: 4.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 3.Pink (Score: -0.7858)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 3.Pink (Score: -0.0982)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 3.Pink (Score: -0.1046)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 3.Pink (Score: -0.1124)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 3.Pink (Score: -0.1050)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 3.Pink (Score: -0.4454)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 4
# Self-Perceived Leader(s): 4.Blue (Ind_Lead: 5.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 4.Orange (Score: -0.3170)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 4.Blue (Score: -0.0324)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 4.Yellow (Score: -0.0373)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 4.Blue (Score: -0.0680)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 4.Orange (Score: -0.0547)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 4.Orange (Score: -0.1858)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 5
# Self-Perceived Leader(s): 5.Blue (Ind_Lead: 4.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 5.Orange (Score: 0.8692)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 5.Orange (Score: 0.0375)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 5.Orange (Score: 0.0438)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 5.Orange (Score: 0.0717)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 5.Orange (Score: 0.0510)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 5.Orange (Score: 0.4601)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 6
# Self-Perceived Leader(s): 6.Green (Ind_Lead: 5.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 6.Orange (Score: 2.5365)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 6.Orange (Score: 0.1584)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 6.Orange (Score: 0.1364)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 6.Orange (Score: 0.1451)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 6.Orange (Score: 0.1466)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 6.Orange (Score: 1.3416)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 7
# Self-Perceived Leader(s): 7.Orange, 7.Green (Ind_Lead: 3.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 7.Orange (Score: 0.8107)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 7.Orange (Score: 0.0507)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 7.Orange (Score: 0.0681)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 7.Orange (Score: 0.0614)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 7.Orange (Score: 0.0601)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 7.Orange (Score: 0.4354)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 8
# Self-Perceived Leader(s): 8.Green (Ind_Lead: 5.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 8.Green (Score: 1.3886)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 8.Green (Score: 0.0868)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 8.Green (Score: 0.1004)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 8.Green (Score: 0.0906)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 8.Green (Score: 0.0926)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 8.Green (Score: 0.7406)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group:

#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 21
# Self-Perceived Leader(s): 21.Blue (Ind_Lead: 5.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 21.Orange (Score: 0.1283)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 21.Orange (Score: 0.0013)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 21.Orange (Score: 0.0035)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 21.Orange (Score: 0.0125)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 21.Orange (Score: 0.0058)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 21.Orange (Score: 0.0671)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 22
# Self-Perceived Leader(s): 22.Blue (Ind_Lead: 4.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 22.Pink (Score: 0.6618)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 22.Pink (Score: 0.0522)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 22.Pink (Score: 0.0336)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 22.Pink (Score: 0.0421)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 22.Pink (Score: 0.0426)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 22.Pink (Score: 0.3522)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 23
# Self-Perceived Leader(s): 23.Orange (Ind_Lead: 5.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 23.Orange (Score: -0.0818)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 23.Orange (Score: -0.0102)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 23.Orange (Score: 0.0004)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 23.Orange (Score: -0.0147)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 23.Orange (Score: -0.0082)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 23.Orange (Score: -0.0450)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 24
# Self-Perceived Leader(s): 24.Blue (Ind_Lead: 4.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 24.Blue (Score: -0.0152)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 24.Blue (Score: 0.0004)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 24.Blue (Score: 0.0022)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 24.Blue (Score: 0.0015)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 24.Blue (Score: 0.0014)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 24.Blue (Score: -0.0069)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 25
# Self-Perceived Leader(s): 25.Pink (Ind_Lead: 5.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 25.Orange (Score: 0.2568)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 25.Orange (Score: 0.0206)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 25.Orange (Score: 0.0052)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 25.Orange (Score: -0.0217)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 25.Orange (Score: 0.0013)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 25.Orange (Score: 0.1291)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 26
# Self-Perceived Leader(s): 26.Pink, 26.Orange (Ind_Lead: 4.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 26.Pink (Score: 0.1615)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 26.Pink (Score: 0.0321)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 26.Pink (Score: 0.0520)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 26.Pink (Score: 0.0081)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 26.Pink (Score: 0.0307)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 26.Pink (Score: 0.0961)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 27
# Self-Perceived Leader(s): 27.Orange (Ind_Lead: 4.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 27.Orange (Score: 0.3753)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 27.Orange (Score: 0.0235)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 27.Orange (Score: 0.0220)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 27.Blue (Score: 0.0081)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 27.Blue (Score: 0.0141)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 27.Orange (Score: 0.1923)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Conversation Group: 28
# Self-Perceived Leader(s): 28.Blue (Ind_Lead: 5.0000)
# ====================================================================================================
# Scheme 'raw_final':
#   Model Winner(s): 28.Blue (Score: -0.2727)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq1':
#   Model Winner(s): 28.Blue (Score: -0.0185)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq2':
#   Model Winner(s): 28.Pink (Score: -0.0017)
#   Match with self-perceived leader(s): No
# ----------------------------------------------------------------------------------------------------
# Scheme 'eq3':
#   Model Winner(s): 28.Blue (Score: -0.0186)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'avg_weighted':
#   Model Winner(s): 28.Blue (Score: -0.0170)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------
# Scheme 'final':
#   Model Winner(s): 28.Blue (Score: -0.1449)
#   Match with self-perceived leader(s): Yes
# ----------------------------------------------------------------------------------------------------

# %%
print("=== Overall Accuracy per Coordination Scheme ===")
for scheme in schemes:
    accuracy = (scheme_match_counts[scheme] / total_groups) * 100 if total_groups > 0 else 0
    print(f"{scheme:<12}: {accuracy:6.2f}% ({scheme_match_counts[scheme]} out of {total_groups} groups)")
# Out:
# === Overall Accuracy per Coordination Scheme ===
# raw_final   :  35.71% (10 out of 28 groups)
# eq1         :  39.29% (11 out of 28 groups)
# eq2         :  32.14% (9 out of 28 groups)
# eq3         :  39.29% (11 out of 28 groups)
# avg_weighted:  32.14% (9 out of 28 groups)
# final       :  35.71% (10 out of 28 groups)
